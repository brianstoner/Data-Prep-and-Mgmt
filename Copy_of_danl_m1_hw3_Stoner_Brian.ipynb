# %% [markdown]
# <a href="https://colab.research.google.com/github/brianstoner/Data-Prep-and-Mgmt/blob/main/Copy_of_danl_m1_hw3_Stoner_Brian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
nyc_payroll = pd.read_csv('https://bcdanl.github.io/data/nyc_payroll_2022_2023.csv')

# %%
nyc_payroll.info()

# %%
nyc_payroll.sort_values(["Agency Name"])

# %% [markdown]
# ### Question 1
# - *Select “First Name”, “Last Name”, “Base Salary”, and “Total OT Paid”, then sort these selected variables by “Base Salary” in descending order and display the top 10 entries.*

# %%
(
nyc_payroll[ ['First Name', 'Last Name', 'Base Salary', 'Total OT Paid' ] ]
  .sort_values(['Base Salary'], ascending=False)
  .head(10)
)

# %% [markdown]
# ### Question 2
# - *Create a new DataFrame that includes employees from the “DEPARTMENT OF EDUCATION ADMIN” agency where the variables are “First Name”, “Last Name”, “Title Description”, “Base Salary”, and “Total OT Paid”. Additionally, include a new variable “Total Compensation” which is the sum of “Base Salary” and “Total OT Paid”.*

# %%
# Assign df variable to the nyc_payroll dataframe
nyc_payroll['Total Compensation'] = nyc_payroll['Base Salary'] + nyc_payroll['Total OT Paid']
nyc_payroll[ ['First Name', 'Last Name', 'Title Description', 'Agency Name', 'Base Salary', 'Total OT Paid' ] ]
nyc_payroll.sort_values(['Agency Name'], ascending=True)
nyc_payroll.loc[(nyc_payroll['Agency Name'] == 'DEPARTMENT OF EDUCATION ADMIN')]

# [ ['First Name', 'Last Name', 'Title Description', 'Agency Name', 'Base Salary', 'Total OT Paid' ] ]
# Out:
#       Fiscal Year  Payroll Number                    Agency Name  \
# 0            2022             740  DEPARTMENT OF EDUCATION ADMIN
# 8            2022             740  DEPARTMENT OF EDUCATION ADMIN
# 18           2022             740  DEPARTMENT OF EDUCATION ADMIN
# 44           2022             740  DEPARTMENT OF EDUCATION ADMIN
# 58           2022             740  DEPARTMENT OF EDUCATION ADMIN
# ...           ...             ...                            ...
# 1764         2023             740  DEPARTMENT OF EDUCATION ADMIN
# 1788         2023             740  DEPARTMENT OF EDUCATION ADMIN
# 1891         2023             740  DEPARTMENT OF EDUCATION ADMIN
# 1894         2023             740  DEPARTMENT OF EDUCATION ADMIN
# 1910         2023             740  DEPARTMENT OF EDUCATION ADMIN
#
#          Last Name First Name Mid Init Agency Start Date  \
# 0            DAVIS      OSCAR      NaN        07/06/2021
# 8       VARNAUSKAS      JENNA        L        09/03/2019
# 18       GRANQUIST  CHRISTINA      NaN        09/24/2017
# 44           QUIAH     SANDRA      NaN        05/17/2016
# 58            EARL    SHATARA        M        03/13/2022
# ...            ...        ...      ...               ...
# 1764          ROSA   DEISMOND      NaN        07/02/2007
# 1788          READ     SERIDE      NaN        06/01/2000
# 1891  CORADO DERAS      ELISA        E        11/16/2021
# 1894        YEARDE     YAZMYN        A        05/11/2022
# 1910     AKINTUNDE   FOLASADE        A        09/21/2014
#
#      Work Location Borough                                  Title Description  \
# 0                    BRONX  SUBSTANCE ABUSE PREVENTION & INTERVENTION SPEC...
# 8                MANHATTAN                             OCCUPATIONAL THERAPIST
# 18                RICHMOND                                 PHYSICAL THERAPIST
# 44               MANHATTAN                                COMMUNITY ASSOCIATE
# 58               MANHATTAN                                PROCUREMENT ANALYST
# ...                    ...                                                ...
# 1764             MANHATTAN                              COMMUNITY COORDINATOR
# 1788             MANHATTAN                              COMMUNITY COORDINATOR
# 1891             MANHATTAN                                COMMUNITY ASSISTANT
# 1894                 BRONX  SUBSTANCE ABUSE PREVENTION & INTERVENTION SPEC...
# 1910                 BRONX                                 PHYSICAL THERAPIST
#
#      Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 0                        CEASED      53820.0  per Annum          805.0
# 8                        ACTIVE      75381.0  per Annum         1664.0
# 18                     ON LEAVE      80270.0  per Annum          576.0
# 44                       ACTIVE      55323.0  per Annum         1820.0
# 58                       ACTIVE      62055.0  per Annum          490.0
# ...                         ...          ...        ...            ...
# 1764                     ACTIVE      82170.0  per Annum         1820.0
# 1788                     ACTIVE      67834.0  per Annum         1820.0
# 1891                     ACTIVE      40765.0  per Annum         1820.0
# 1894                     ACTIVE      58811.0  per Annum         1610.0
# 1910                     ACTIVE      80730.0  per Annum         1664.0
#
#       Regular Gross Paid  OT Hours  Total OT Paid  Total Other Pay  \
# 0               24469.41      0.00           0.00             0.00
# 8               74761.74      0.00           0.00          5462.82
# 18              24630.80      0.00           0.00          5194.66
# 44              55171.48      0.00           0.00             0.00
# 58              16661.33      0.00           0.00             0.00
# ...                  ...       ...            ...              ...
# 1764            82262.42     22.75        1602.93          3140.75
# 1788            58521.00     15.00         639.27          6121.86
# 1891            36570.82      0.00           0.00          3000.00
# 1894            44583.28      0.00           0.00          6698.55
# 1910            80508.74      0.00           0.00         11051.79
#
#       Total Compensation
# 0               53820.00
# 8               75381.00
# 18              80270.00
# 44              55323.00
# 58              62055.00
# ...                  ...
# 1764            83772.93
# 1788            68473.27
# 1891            40765.00
# 1894            58811.00
# 1910            80730.00
#
# [73 rows x 18 columns]

# %%
nyc_payroll["Total Compensation"] = nyc_payroll["Base Salary"] + nyc_payroll["Total OT Paid"]
nyc_payroll

# %%
nyc_payroll.reset_index()
# Out:
#       index  Fiscal Year  Payroll Number                     Agency Name  \
# 0         0         2022             740   DEPARTMENT OF EDUCATION ADMIN
# 1         1         2022             746    DEPT OF ED PER DIEM TEACHERS
# 2         2         2022             747  DEPT OF ED PER SESSION TEACHER
# 3         3         2022             742          DEPT OF ED PEDAGOGICAL
# 4         4         2022             742          DEPT OF ED PEDAGOGICAL
# ...     ...          ...             ...                             ...
# 1995   1995         2023             300  BOARD OF ELECTION POLL WORKERS
# 1996   1996         2023             742          DEPT OF ED PEDAGOGICAL
# 1997   1997         2023             747  DEPT OF ED PER SESSION TEACHER
# 1998   1998         2023             747  DEPT OF ED PER SESSION TEACHER
# 1999   1999         2023             827        DEPARTMENT OF SANITATION
#
#      Last Name First Name Mid Init Agency Start Date Work Location Borough  \
# 0        DAVIS      OSCAR      NaN        07/06/2021                 BRONX
# 1         ZHOU        JUN      NaN        07/01/2020             MANHATTAN
# 2        LOPEZ    YERIBEL        E        12/11/2001             MANHATTAN
# 3      KENNEDY       VERA        R        04/08/2016             MANHATTAN
# 4      LICHVAR     AMANDA        C        02/01/2007             MANHATTAN
# ...        ...        ...      ...               ...                   ...
# 1995    GARNER   GEOFFREY        O        01/01/2020             MANHATTAN
# 1996  FIGUEROA    JESSICA        A        02/08/2006             MANHATTAN
# 1997   DIFORTE   DANIELLE        N        09/05/2017             MANHATTAN
# 1998    BIONDO   STEFANIE      NaN        10/03/2011             MANHATTAN
# 1999     ARIAS    ELPIDIO      NaN        07/11/2022             MANHATTAN
#
#                                       Title Description  \
# 0     SUBSTANCE ABUSE PREVENTION & INTERVENTION SPEC...
# 1                                    TEACHER-GENERAL ED
# 2                                  TEACHER- PER SESSION
# 3                                               TEACHER
# 4                             TEACHER SPECIAL EDUCATION
# ...                                                 ...
# 1995                                    ELECTION WORKER
# 1996                                 TEACHER ASSIGNED A
# 1997                               TEACHER- PER SESSION
# 1998                               TEACHER- PER SESSION
# 1999                                  SANITATION WORKER
#
#      Leave Status as of June 30  Base Salary  Pay Basis  Regular Hours  \
# 0                        CEASED     53820.00  per Annum          805.0
# 1                        ACTIVE       110.29    per Day            0.0
# 2                        ACTIVE        33.18    per Day            0.0
# 3                        ACTIVE     79687.00  per Annum            0.0
# 4                        ACTIVE    109852.00  per Annum            0.0
# ...                         ...          ...        ...            ...
# 1995                     ACTIVE         1.00   per Hour            0.0
# 1996                     ACTIVE    109852.00  per Annum            0.0
# 1997                     ACTIVE        33.18    per Day            0.0
# 1998                     ACTIVE        33.18    per Day            0.0
# 1999                     ACTIVE     44064.00  per Annum         2000.0
#
#       Regular Gross Paid  OT Hours  Total OT Paid  Total Other Pay  \
# 0               24469.41       0.0           0.00             0.00
# 1                3387.59       0.0           0.00             0.00
# 2               20242.24       0.0           0.00           474.32
# 3               74904.27       0.0           0.00         -4474.44
# 4              109852.08       0.0           0.00          5380.44
# ...                  ...       ...            ...              ...
# 1995              928.00       0.0           0.00             0.00
# 1996           109852.08       0.0           0.00             0.00
# 1997             1824.57       0.0           0.00             0.00
# 1998             4384.04       0.0           0.00             0.61
# 1999            40473.72     128.5        5659.77         10995.37
#
#       Total Compensation  Total_Compensation
# 0               53820.00            53820.00
# 1                 110.29              110.29
# 2                  33.18               33.18
# 3               79687.00            79687.00
# 4              109852.00           109852.00
# ...                  ...                 ...
# 1995                1.00                1.00
# 1996           109852.00           109852.00
# 1997               33.18               33.18
# 1998               33.18               33.18
# 1999            49723.77            49723.77
#
# [2000 rows x 20 columns]
